# %% [markdown]
# ## Creating Databases in MySQL

# %%
import mysql.connector as sql

# %%
connection = sql.connect(
    host="localhost",
    username="root", 
    password="Shu@1995" 
)
print(connection)

# %% [markdown]
# ## Creating Databases

# %%
cursor=connection.cursor()
cursor.execute("Create database Data")

# %%
cursor.execute("SHOW DATABASES")

# %% [markdown]
# The database which we have creted we can check in th mysql workbech weather its showing there or not

# %% [markdown]
# Let's print the databases here

# %%
for x in cursor:
     print(x)
# Out:
# ('data',)
# ('employees',)
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('shu',)
# ('sys',)
# ('world',)

# %% [markdown]
# The Databases we have have created which is Data we can see here. Let's check on workbench weather its showing or not

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %%
we can see the database which we have created

# %% [markdown]
# ## Drop Some Databases

# %%
cursor.execute("DROP DATABASE DATA")

# %%
cursor.execute("SHOW DATABASES")

# %%
for y in cursor:
    print(y)
# Out:
# ('employees',)
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('shu',)
# ('sys',)
# ('world',)

# %% [markdown]
# Will check in MYSQL workbench

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# We can see there we have successfully removed database
